# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tom = pd.read_csv('../thomas.csv')

# %%
tom.head()
# Out:
#      imdb_id                           title rating
# 0  tt0119654                    Men in Black      4
# 1  tt2103281  Dawn of the Planet of the Apes      ?
# 2  tt0382932                     Ratatouille      4
# 3  tt0482571                    The Prestige      ?
# 4  tt0407887                    The Departed      ?

# %%
tom['rating'] = tom['rating'].replace('?', np.nan).astype(np.float64)

# %%
print(f"Unseen movies make up {tom['rating'].isna().sum()} of all {tom['imdb_id'].nunique()}")
# Out:
# Unseen movies make up 131 of all 199

# %%
sns.countplot(x='rating', data=tom)
